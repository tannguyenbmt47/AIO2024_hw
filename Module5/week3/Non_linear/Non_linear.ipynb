# %%
# !gdown --id 1SqSn_8rxkk-Qvu4JLMcN_3ZFGDNa6P_V
# Out:
# /media/tan/F/AIO2024_hw/env/lib/python3.10/site-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1SqSn_8rxkk-Qvu4JLMcN_3ZFGDNa6P_V
# To: /media/tan/F/AIO2024_hw/AIO2024_hw/Module5/week3/NonLinear_data.npy
# 100%|██████████████████████████████████████| 5.57k/5.57k [00:00<00:00, 6.24MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
random_state = 50
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(random_state)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
data_path = 'NonLinear_data.npy'
data = np.load(data_path, allow_pickle=True).item() 
X, y = data['X'], data['labels']
print(X.shape, y.shape)
# Out:
# (300, 2) (300,)

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=val_size, random_state=random_state, shuffle=is_shuffle)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=test_size, random_state=random_state, shuffle=is_shuffle)

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)
y_val = torch.tensor(y_val, dtype=torch.long)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
batch_size = 32
train_loader = DataLoader(CustomDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
val_loader = DataLoader(CustomDataset(X_val, y_val), batch_size=batch_size, shuffle=False)
test_loader = DataLoader(CustomDataset(X_test, y_test), batch_size=batch_size, shuffle=False)

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        self.softmax = nn.Softmax(dim=1)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.linear1(x)
        x = self.tanh(x)
        out = self.output(x)
        return out.squeeze(1)

# %%
input_dims = X_train.shape[1]
output_dims = torch.unique(y_train).shape[0]
hidden_dims = 512

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

# %%
lr = 1e-1
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD( model.parameters(), lr=lr)

# %%
def compute_accuracy(y_hat, y_true):
    _, y_hat = torch.max(y_hat, dim=1)
    correct = (y_hat == y_true).sum().item()
    accuracy = correct / len(y_true)
    return accuracy

# %%
epochs = 100
train_losses = []
val_losses = []
train_accs = []
val_accs = []

for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    train_predict = []
    model.train()
    
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_predict.append(outputs.detach().cpu())
        train_target.append(y_samples.cpu())
    
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    
    train_predict = torch.cat(train_predict)
    train_target = torch.cat(train_target)
    train_acc = compute_accuracy(train_predict, train_target)
    train_accs.append(train_acc)
    
    val_loss = 0.0
    val_target = []
    val_predict = []
    model.eval()
    
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            val_loss += criterion(outputs, y_samples).item()
            val_predict.append(outputs.cpu())
            val_target.append(y_samples.cpu())
    
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    
    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = compute_accuracy(val_predict, val_target)
    val_accs.append(val_acc)
    
    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 0.799	Validation loss: 1.018
#
# EPOCH 2:	Training loss: 0.862	Validation loss: 1.073
#
# EPOCH 3:	Training loss: 0.870	Validation loss: 0.941
#
# EPOCH 4:	Training loss: 0.751	Validation loss: 0.824
#
# EPOCH 5:	Training loss: 0.924	Validation loss: 1.561
#
# EPOCH 6:	Training loss: 0.890	Validation loss: 1.078
#
# EPOCH 7:	Training loss: 0.833	Validation loss: 1.359
#
# EPOCH 8:	Training loss: 0.860	Validation loss: 0.942
#
# EPOCH 9:	Training loss: 0.690	Validation loss: 0.818
#
# EPOCH 10:	Training loss: 0.709	Validation loss: 0.752
#
# EPOCH 11:	Training loss: 0.730	Validation loss: 0.898
#
# EPOCH 12:	Training loss: 0.659	Validation loss: 0.872
#
# EPOCH 13:	Training loss: 0.607	Validation loss: 0.847
#
# EPOCH 14:	Training loss: 0.760	Validation loss: 0.937
#
# EPOCH 15:	Training loss: 0.656	Validation loss: 0.756
#
# EPOCH 16:	Training loss: 0.690	Validation loss: 0.690
#
# EPOCH 17:	Training loss: 0.611	Validation loss: 0.844
#
# EPOCH 18:	Training loss: 0.716	Validation loss: 0.797
#
# EPOCH 19:	Training loss: 0.593	Validation loss: 0.699
#
# EPOCH 20:	Training loss: 0.615	Validation loss: 0.656
#
# EPOCH 21:	Training loss: 0.542	Validation loss: 0.830
#
# EPOCH 22:	Training loss: 0.600	Validation loss: 0.666
#
# EPOCH 23:	Training loss: 0.553	Validation loss: 0.663
#
# EPOCH 24:	Training loss: 0.543	Validation loss: 0.679
#
# EPOCH 25:	Training loss: 0.569	Validation loss: 0.690
#
# EPOCH 26:	Training loss: 0.489	Validation loss: 0.675
#
# EPOCH 27:	Training loss: 0.515	Validation loss: 0.779
#
# EPOCH 28:	Training loss: 0.581	Validation loss: 0.767
#
# EPOCH 29:	Training loss: 0.598	Validation loss: 0.693
#
# EPOCH 30:	Training loss: 0.540	Validation loss: 0.851
#
# EPOCH 31:	Training loss: 0.490	Validation loss: 0.662
#
# EPOCH 32:	Training loss: 0.443	Validation loss: 0.626
#
# EPOCH 33:	Training loss: 0.477	Validation loss: 0.529
#
# EPOCH 34:	Training loss: 0.468	Validation loss: 0.804
#
# EPOCH 35:	Training loss: 0.561	Validation loss: 0.855
#
# EPOCH 36:	Training loss: 0.480	Validation loss: 0.594
#
# EPOCH 37:	Training loss: 0.410	Validation loss: 0.532
#
# EPOCH 38:	Training loss: 0.417	Validation loss: 0.517
#
# EPOCH 39:	Training loss: 0.439	Validation loss: 0.674
#
# EPOCH 40:	Training loss: 0.433	Validation loss: 0.597
#
# EPOCH 41:	Training loss: 0.412	Validation loss: 0.536
#
# EPOCH 42:	Training loss: 0.364	Validation loss: 0.563
#
# EPOCH 43:	Training loss: 0.405	Validation loss: 0.512
#
# EPOCH 44:	Training loss: 0.402	Validation loss: 0.606
#
# EPOCH 45:	Training loss: 0.388	Validation loss: 0.547
#
# EPOCH 46:	Training loss: 0.356	Validation loss: 0.490
#
# EPOCH 47:	Training loss: 0.372	Validation loss: 0.461
#
# EPOCH 48:	Training loss: 0.368	Validation loss: 0.457
#
# EPOCH 49:	Training loss: 0.350	Validation loss: 0.493
#
# EPOCH 50:	Training loss: 0.333	Validation loss: 0.595
#
# EPOCH 51:	Training loss: 0.354	Validation loss: 0.482
#
# EPOCH 52:	Training loss: 0.325	Validation loss: 0.520
#
# EPOCH 53:	Training loss: 0.323	Validation loss: 0.399
#
# EPOCH 54:	Training loss: 0.315	Validation loss: 0.440
#
# EPOCH 55:	Training loss: 0.324	Validation loss: 0.441
#
# EPOCH 56:	Training loss: 0.355	Validation loss: 0.449
#
# EPOCH 57:	Training loss: 0.329	Validation loss: 0.413
#
# EPOCH 58:	Training loss: 0.298	Validation loss: 0.475
#
# EPOCH 59:	Training loss: 0.302	Validation loss: 0.535
#
# EPOCH 60:	Training loss: 0.333	Validation loss: 0.423
#
# EPOCH 61:	Training loss: 0.294	Validation loss: 0.400
#
# EPOCH 62:	Training loss: 0.300	Validation loss: 0.452
#
# EPOCH 63:	Training loss: 0.330	Validation loss: 0.558
#
# EPOCH 64:	Training loss: 0.298	Validation loss: 0.380
#
# EPOCH 65:	Training loss: 0.297	Validation loss: 0.391
#
# EPOCH 66:	Training loss: 0.260	Validation loss: 0.417
#
# EPOCH 67:	Training loss: 0.265	Validation loss: 0.411
#
# EPOCH 68:	Training loss: 0.264	Validation loss: 0.442
#
# EPOCH 69:	Training loss: 0.276	Validation loss: 0.413
#
# EPOCH 70:	Training loss: 0.287	Validation loss: 0.394
#
# EPOCH 71:	Training loss: 0.258	Validation loss: 0.380
#
# EPOCH 72:	Training loss: 0.239	Validation loss: 0.396
#
# EPOCH 73:	Training loss: 0.250	Validation loss: 0.357
#
# EPOCH 74:	Training loss: 0.247	Validation loss: 0.405
#
# EPOCH 75:	Training loss: 0.255	Validation loss: 0.366
#
# EPOCH 76:	Training loss: 0.243	Validation loss: 0.394
#
# EPOCH 77:	Training loss: 0.257	Validation loss: 0.358
#
# EPOCH 78:	Training loss: 0.234	Validation loss: 0.423
#
# EPOCH 79:	Training loss: 0.249	Validation loss: 0.357
#
# EPOCH 80:	Training loss: 0.236	Validation loss: 0.326
#
# EPOCH 81:	Training loss: 0.226	Validation loss: 0.390
#
# EPOCH 82:	Training loss: 0.228	Validation loss: 0.334
#
# EPOCH 83:	Training loss: 0.215	Validation loss: 0.358
#
# EPOCH 84:	Training loss: 0.230	Validation loss: 0.335
#
# EPOCH 85:	Training loss: 0.225	Validation loss: 0.366
#
# EPOCH 86:	Training loss: 0.224	Validation loss: 0.336
#
# EPOCH 87:	Training loss: 0.233	Validation loss: 0.328
#
# EPOCH 88:	Training loss: 0.228	Validation loss: 0.348
#
# EPOCH 89:	Training loss: 0.210	Validation loss: 0.302
#
# EPOCH 90:	Training loss: 0.215	Validation loss: 0.328
#
# EPOCH 91:	Training loss: 0.239	Validation loss: 0.341
#
# EPOCH 92:	Training loss: 0.207	Validation loss: 0.349
#
# EPOCH 93:	Training loss: 0.200	Validation loss: 0.335
#
# EPOCH 94:	Training loss: 0.205	Validation loss: 0.351
#
# EPOCH 95:	Training loss: 0.194	Validation loss: 0.309
#
# EPOCH 96:	Training loss: 0.203	Validation loss: 0.292
#
# EPOCH 97:	Training loss: 0.191	Validation loss: 0.319
#
# EPOCH 98:	Training loss: 0.186	Validation loss: 0.322
#
# EPOCH 99:	Training loss: 0.186	Validation loss: 0.320
#
# EPOCH 100:	Training loss: 0.192	Validation loss: 0.334

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %%
test_target = []
test_predict = []
model.eval()

with torch.no_grad():
    for X_samples, y_samples in test_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        outputs = model(X_samples)
        test_predict.append(outputs.cpu())
        test_target.append(y_samples.cpu())

test_predict = torch.cat(test_predict)
test_target = torch.cat(test_target)
test_acc = compute_accuracy(test_predict, test_target)

print('Evaluation on test set:')
print(f'Accuracy: {test_acc}')
# Out:
# Evaluation on test set:
# Accuracy: 0.9
